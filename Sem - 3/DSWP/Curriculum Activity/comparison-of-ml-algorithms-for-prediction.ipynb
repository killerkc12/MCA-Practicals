# %% [markdown]
# # Introduction
#
# I will comparison ML Classification Algorithms.
#
# 1. Logistic Regression
# 2. KNN
# 3. SVM
# 4. Naive B.
# 5. Random Forest
#
# <img src="https://mobilemonitoringsolutions.com/wp-content/uploads/2018/09/mldepressiongif.gif" width="500px">

# %% [markdown]
# ## Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

#Visualization
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap 
#Libraries for ML
from sklearn.preprocessing import StandardScaler #Standardizasyon için
from sklearn.model_selection import train_test_split, GridSearchCV #GridSearchCV: KNN ile ilgili en iyi parametreleri belirlemek
from sklearn.metrics import accuracy_score ,confusion_matrix #Sonuç değerlendirme
from sklearn.neighbors import KNeighborsClassifier,LocalOutlierFactor #Trainin algoritması ve NCA ve Outlier değerler için
from sklearn.decomposition import PCA #PCA için

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# plotly
import chart_studio.plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import itertools
plt.style.use('fivethirtyeight')
import seaborn as sns
# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# Any results you write to the current directory are saved as output.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Read and Examination Dataset

# %%
#read data
data = pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Split Data as M&B
p = data[data.Outcome == 1]
n = data[data.Outcome == 0]

# %% [markdown]
# # Visualization

# %%
sns.countplot(x='Outcome',data=data)
plt.title("Count 0 & 1")
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print('Data Shape',data.shape)
print(data.info()) 
describe = data.describe()
describe.T
# Out:
# Data Shape (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
corr_data = data.corr() 
sns.clustermap(corr_data,annot= True,fmt = '.2f')
plt.title('Correlation Between Features')
plt.show();

# %% [markdown]
# ## Feautre Visualization with Box plot [Before Standardization]

# %%
#Box p. öncesi bir melted işlemi gerekitor.
data_melted = pd.melt(data,id_vars='Outcome',
                      var_name='Features',
                      value_name='Value')

plt.figure()
sns.boxplot(x='Features',y='Value',hue='Outcome',data=data_melted) #Featureslar target'a göre ayrıldı.
plt.xticks(rotation=75) #Feature isimleri 90 derece dik görülecek.
plt.show()

"""
We will need standardization.
"""
# Out:
# '\nWe will need standardization.\n'

# %% [markdown]
# ## Analysis of Diabetic Cases

# %%
#General Analysis

data1 = data[data["Outcome"]==1]
columns = data.columns[:8]
plt.subplots(figsize=(18,18))
length =len(columns)
for i,j in itertools.zip_longest(columns,range(length)):
    plt.subplot((length/2),3,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    plt.ylabel("Count")
    data1[i].hist(bins=20,edgecolor='black')
    plt.title(i)
plt.show()

# %% [markdown]
# ## Analysis of Non-Diabetic Cases

# %%
#General Analysis

data1 = data[data["Outcome"]==0]
columns = data.columns[:8]
plt.subplots(figsize=(18,18))
length =len(columns)
for i,j in itertools.zip_longest(columns,range(length)):
    plt.subplot((length/2),3,j+1)
    plt.subplots_adjust(wspace=0.2,hspace=0.5)
    plt.ylabel("Count")
    data1[i].hist(bins=20,edgecolor='black')
    plt.title(i)
plt.show()

# %% [markdown]
# ## Visualization, Scatter Plot

# %%
plt.scatter(p.Pregnancies,p.Glucose,color = "brown",label="Diabet Positive",alpha=0.4)
plt.scatter(n.Pregnancies,n.Glucose,color = "Orange",label="Diabet Negative",alpha=0.2)
plt.xlabel("Pregnancies")
plt.ylabel("Glucose")
plt.legend()
plt.show()

#We appear that it is clear segregation.

# %%
#Visualization, Scatter Plot

plt.scatter(p.Age,p.Pregnancies,color = "lime",label="Diabet Positive",alpha=0.4)
plt.scatter(n.Age,n.Pregnancies,color = "black",label="Diabet Negative",alpha=0.2)
plt.xlabel("Age")
plt.ylabel("Pregnancies")
plt.legend()
plt.show()

#We appear that it is clear segregation.

# %%
#Visualization, Scatter Plot

plt.scatter(p.Glucose,p.Insulin,color = "lime",label="Diabet Positive",alpha=0.4)
plt.scatter(n.Glucose,n.Insulin,color = "black",label="Diabet Negative",alpha=0.1)
plt.xlabel("Glucose")
plt.ylabel("Insulin")
plt.legend()
plt.show()

#We appear that it is clear segregation.

# %% [markdown]
# ## Outlier Detection

# %%
x = data.drop(['Outcome'],axis=1) 
y = data.Outcome
columns = x.columns.tolist() # Featureların isimlerini bir listede topladık.

clf = LocalOutlierFactor() #KNN değeri gerekiyor. Tanımlı değeri 20 ve bizde 20 kullanacağız. O nedenle birşey yazmayacağız.
y_pred = clf.fit_predict(x) #LOF uygulayıo negetif outlier f. alıyoruz.

x_score = clf.negative_outlier_factor_
outlier_score = pd.DataFrame()
outlier_score['score'] = x_score

threshold_outliers = -1.5
filtre = outlier_score['score'] < threshold_outliers
outlier_index = outlier_score[filtre].index.tolist() #outlier değerlerine threshold uygulanmış olanları bir listeye attık

plt.figure()
plt.scatter(x.iloc[outlier_index,0], x.iloc[outlier_index,1],color = 'blue',s=50,label='outliers')
plt.scatter(x.iloc[:,0]
            ,x.iloc[:,1],color='k',s=3,label='data_point') #s : boyut

radius = (x_score.max() - x_score ) / (x_score.max() - x_score.min() ) #Değerleri normalize ederek biası önledik
outlier_score['radius '] = radius

plt.scatter(x.iloc[:,0], x.iloc[:,1], s=1000*radius, edgecolors='r',facecolor='none',label='Outlier skores')
plt.legend()
plt.show();

# %% [markdown]
# ## Drop Outliers

# %%
x = x.drop(outlier_index) #outliers remove
y = y.drop(outlier_index).values #outliers remove

# %% [markdown]
# ## Train - Tespt Split

# %%
test_size = 0.3

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=test_size,random_state=42)

# %% [markdown]
# ## Standardizasyon

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train) #scaler isimli bir değişkene Standartscaler metodunu atayıp sonra bu değişken aracılığıyla xtraindeki verileri standardize ettik

x_test = scaler.transform(x_test)

x_train_df = pd.DataFrame(x_train,columns=columns)
x_train_df_describe = x_train_df.describe()
x_train_df['target'] = y_train

# %% [markdown]
# ## Box Plot Visualization after the Standardization

# %%
data_melted = pd.melt(x_train_df,id_vars='target',
                      var_name='Features',
                      value_name='Value')

plt.figure()
sns.boxplot(x='Features',y='Value',hue='target',data=data_melted) #Featureslar target'a göre ayrıldı.
plt.xticks(rotation=75) #Feature isimleri 90 derece dik görülecek.
plt.show()

# %% [markdown]
# # Comparison of ML Classification Algorithms

# %% [markdown]
# # Logistic Regression Classification

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
#K-fold CV
from sklearn.model_selection import cross_val_score
accuraccies = cross_val_score(estimator = LR, X= x_train, y=y_train, cv=10)
print("Average Accuracies: ",np.mean(accuraccies))
print("Standart Deviation Accuracies: ",np.std(accuraccies))
# Out:
# Average Accuracies:  0.7587082728592163
# Standart Deviation Accuracies:  0.0593241656716101

# %%
LR.fit(x_train,y_train)
print("Test Accuracy {}".format(LR.score(x_test,y_test))) 

LRscore = LR.score(x_test,y_test)
# Out:
# Test Accuracy 0.8088888888888889

# %%
#Confusion Matrix

yprediciton1= LR.predict(x_test)
ytrue = y_test

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue,yprediciton1)

#CM visualization

import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(CM,annot = True, linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()

# %% [markdown]
# # K-NN

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train) #Calculation (In the supervise learning this section = training)
y_predict = knn.predict(x_test) #Test Section
cm = confusion_matrix(y_test, y_predict) #Plooting
acc = accuracy_score(y_test, y_predict) #Accuracy Score
score = knn.score(x_test, y_test) #acc ile burasının sonucu aynı çıkacak. Doğrulama amaçlı yapılıyor.

print("Score:",score)
print("CM:",cm)
print("Basic KNN Acc:",acc)
# Out:
# Score: 0.7066666666666667
# CM: [[135  10]
#  [ 56  24]]
# Basic KNN Acc: 0.7066666666666667

# %%
def KNN_best_parameters(x_train,x_test,y_train,y_test):
    
    k_range = list(range(1,51)) #En uygun k değeri buluma
    weight_options = ['uniform','distance'] #En uygun weighti buluma
    #manhattan_distance = 1
    #euclidean_distance = 2
    distance_options = [1,2] #En uygun distance type buluma
    print()
    param_grid = dict(n_neighbors=k_range,weights=weight_options,p=distance_options) #Aranacak parametreleri bir sözlükte topladık.

    knn =KNeighborsClassifier() #Parametrelerin deneneceği knn oluşturuldu.
    grid = GridSearchCV(knn,param_grid,cv=10,scoring='accuracy') #Parametrelerin aranması için method
    grid.fit(x_train, y_train) #fitting ile best parm. elde edildi
    
    print('Best training score: {} with parametres: {}'.format(grid.best_score_,grid.best_params_))
    print()
    
    knn = KNeighborsClassifier(**grid.best_params_) #Test setinde deneme işlemi için
    knn.fit(x_train, y_train)
    
    y_predict_test = knn.predict(x_test)
    y_predict_train = knn.predict(x_train)

    cm_test = confusion_matrix(y_test,y_predict_test)
    cm_train = confusion_matrix(y_train,y_predict_train)

    acc_test = accuracy_score(y_test,y_predict_test)  
    acc_train = accuracy_score(y_train,y_predict_train)

    print('Test Score: {}, Train Score: {}'.format(acc_test,acc_train))
    print()
    print('CM Test:',cm_test)
    print('CM Train:',cm_train)
    
    return grid

# %%
grid = KNN_best_parameters(x_train,x_test,y_train,y_test)
# Out:
# Best training score: 0.7642235123367199 with parametres: {'n_neighbors': 36, 'p': 1, 'weights': 'distance'}
#
# Test Score: 0.8177777777777778, Train Score: 1.0
#
# CM Test: [[137   8]
#  [ 33  47]]
# CM Train: [[342   0]
#  [  0 180]]

# %%
KNNscore = grid.best_score_

# %%
#%% PCA

scale = StandardScaler()
x_scaled = scaler.fit_transform(x) #x verisi bölünmeden tam bir şekilde PCA için scale edildi. 

pca = PCA(n_components=2) #2 componentli bir PCA oluşturduk.
pca.fit(x_scaled)
x_reduce_pca = pca.transform(x_scaled) #2feature'a yani boyuta düşürülmüş x 
pca_data =pd.DataFrame(x_reduce_pca,columns=['p1','p2']) #reduce datadan incelemek için bir dataframe oluşturuldu
pca_data['target'] = y #buna target eklendi. Görselleştirmek için gerekli.

sns.scatterplot(x='p1',y='p2',hue='target',data=pca_data) # targeta göre renklendirilmiş grafik
plt.title('PCA: P1 Vs P2')
# Out:
# Text(0.5, 1.0, 'PCA: P1 Vs P2')

# %%
x_train_pca, x_test_pca, y_train_pca, y_test_pca = train_test_split(x_reduce_pca,y,test_size=test_size,random_state=42)

grid_pca = KNN_best_parameters(x_train_pca, x_test_pca, y_train_pca, y_test_pca)
#en iyi parametreleri elde ettiğimiz metodu PCA için çalıştırıyorum.
# Out:
# Best training score: 0.7277576197387519 with parametres: {'n_neighbors': 14, 'p': 1, 'weights': 'uniform'}
#
# Test Score: 0.7333333333333333, Train Score: 0.7509578544061303
#
# CM Test: [[125  20]
#  [ 40  40]]
# CM Train: [[305  37]
#  [ 93  87]]

# %%
cmap_light = ListedColormap(['orange',  'cornflowerblue'])
cmap_bold = ListedColormap(['darkorange', 'darkblue'])

h = .05 # step size in the mesh
X = x_reduce_pca
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = grid_pca.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold,
            edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("%i-Class classification (k = %i, weights = '%s')"
          % (len(np.unique(y)),grid_pca.best_estimator_.n_neighbors, grid_pca.best_estimator_.weights))
# Out:
# Text(0.5, 1.0, "2-Class classification (k = 14, weights = 'uniform')")

# %%
#Confusion Matrix

yprediciton2= knn.predict(x_test)
ytrue = y_test

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue,yprediciton2)

#CM visualization

import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(CM,annot = True, linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()

# %% [markdown]
# # SVM

# %%
#SVM with Sklearn

from sklearn.svm import SVC

SVM = SVC(random_state=42)

# %%
#K-fold CV
from sklearn.model_selection import cross_val_score
accuraccies = cross_val_score(estimator = SVM, X= x_train, y=y_train, cv=5)
print("Average Accuracies: ",np.mean(accuraccies))
print("Standart Deviation Accuracies: ",np.std(accuraccies))
# Out:
# Average Accuracies:  0.7412820512820513
# Standart Deviation Accuracies:  0.03222565856288667

# %%
SVM.fit(x_train,y_train)  #learning 
#SVM Test 
print ("SVM Accuracy:", SVM.score(x_test,y_test))

SVMscore = SVM.score(x_test,y_test)
# Out:
# SVM Accuracy: 0.7866666666666666

# %%
#Confusion Matrix

yprediciton3= SVM.predict(x_test)
ytrue = y_test

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue,yprediciton3)

#CM visualization

import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(CM,annot = True, linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()

# %% [markdown]
# # Naive Bayes Classification

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()

# %%
#K-fold CV
from sklearn.model_selection import cross_val_score
accuraccies = cross_val_score(estimator = NB, X= x_train, y=y_train, cv=35)
print("Average Accuracies: ",np.mean(accuraccies))
print("Standart Deviation Accuracies: ",np.std(accuraccies))
# Out:
# Average Accuracies:  0.7549659863945577
# Standart Deviation Accuracies:  0.11221677652262926

# %%
NB.fit(x_train,y_train) #learning
#prediction
print("Accuracy of NB Score: ", NB.score(x_test,y_test))

NBscore= NB.score(x_test,y_test)
# Out:
# Accuracy of NB Score:  0.7466666666666667

# %%
#Confusion Matrix

yprediciton4= NB.predict(x_test)
ytrue = y_test

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue,yprediciton4)

#CM visualization

import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(CM,annot = True, linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()

# %% [markdown]
# # Decision Tree
# <img src="https://emerj.com/wp-content/uploads/2018/04/3049155-poster-p-1-machine-learning-is-just-a-big-game-of-plinko.gif" width="500px">

# %%
#Decision Tree Algorithm

from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()

# %%
#K-fold CV
from sklearn.model_selection import cross_val_score
accuraccies = cross_val_score(estimator = DTC, X= x_train, y=y_train, cv=55)
print("Average Accuracies: ",np.mean(accuraccies))
print("Standart Deviation Accuracies: ",np.std(accuraccies))
# Out:
# Average Accuracies:  0.7123232323232321
# Standart Deviation Accuracies:  0.1353661987141206

# %%
DTC.fit(x_train,y_train) #learning
#prediciton
print("Decision Tree Score: ",DTC.score(x_test,y_test))
DTCscore = DTC.score(x_test,y_test)
# Out:
# Decision Tree Score:  0.7111111111111111

# %%
#Confusion Matrix

yprediciton5= DTC.predict(x_test)
ytrue = y_test

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue,yprediciton5)

#CM visualization

import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(CM,annot = True, linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()

# %% [markdown]
# # Random Forest

# %%
#Decision Tree Algorithm

from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()
DTC.fit(x_train,y_train) #learning
#prediciton
print("Decision Tree Score: ",DTC.score(x_test,y_test))
# Out:
# Decision Tree Score:  0.7022222222222222

# %%
#Random Forest

from sklearn.ensemble import RandomForestClassifier
RFC= RandomForestClassifier(n_estimators = 82, random_state=42) #n_estimator = DT

# %%
#K-fold CV
from sklearn.model_selection import cross_val_score
accuraccies = cross_val_score(estimator = RFC, X= x_train, y=y_train, cv=10)
print("Average Accuracies: ",np.mean(accuraccies))
print("Standart Deviation Accuracies: ",np.std(accuraccies))
# Out:
# Average Accuracies:  0.7663280116110305
# Standart Deviation Accuracies:  0.06465725630236509

# %%
RFC.fit(x_train,y_train) # learning
print("Random Forest Score: ",RFC.score(x_test,y_test))
RFCscore=RFC.score(x_test,y_test)
# Out:
# Random Forest Score:  0.8177777777777778

# %%
#Find Optimum K value
scores = []
for each in range(80,100):
    RFfind = RandomForestClassifier(n_estimators = each)
    RFfind.fit(x_train,y_train)
    scores.append(RFfind.score(x_test,y_test))
    
plt.figure(1, figsize=(10, 5))
plt.plot(range(80,100),scores,color="black",linewidth=2)
plt.title("Optimum N Estimator Value")
plt.xlabel("N Estimators")
plt.ylabel("Score(Accuracy)")
plt.grid(True)
plt.show()

# %%
#Confusion Matrix

yprediciton6= RFC.predict(x_test)
ytrue = y_test

from sklearn.metrics import confusion_matrix
CM = confusion_matrix(ytrue,yprediciton6)

#CM visualization

import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(CM,annot = True, linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("Prediction(Ypred)")
plt.ylabel("Ytrue")
plt.show()

# %% [markdown]
# # Artificial Neural Network

# %%
#Import Library
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential 
from keras.layers import Dense

# %%
def buildclassifier():
    classifier = Sequential() #initialize NN
    classifier.add(Dense(units = 24, kernel_initializer = 'uniform',activation = 'relu', input_dim =x_train.shape[1]))
    classifier.add(Dense(units = 24, kernel_initializer = 'uniform',activation = 'relu'))
    classifier.add(Dense(units = 24, kernel_initializer = 'uniform',activation = 'relu'))
    classifier.add(Dense(units = 24, kernel_initializer = 'uniform',activation = 'relu'))
    classifier.add(Dense(units = 24, kernel_initializer = 'uniform',activation = 'relu'))
    classifier.add(Dense(units = 24, kernel_initializer = 'uniform',activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform',activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])
    return classifier

# %%
classifier = KerasClassifier(build_fn = buildclassifier, epochs = 500)
accuracies = cross_val_score(estimator = classifier, X = x_train, y= y_train, cv = 5)
mean = accuracies.mean()
variance = accuracies.std()
print("Accuracy mean: "+ str(mean))
print("Accuracy variance: "+ str(variance))
# Out:
# Epoch 1/500
# 14/14 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.6475
# Epoch 2/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.6475
# Epoch 3/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.6475
# Epoch 4/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6817 - accuracy: 0.6475
# Epoch 5/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.6475
# Epoch 6/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.6475
# Epoch 7/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6153 - accuracy: 0.6475
# Epoch 8/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5591 - accuracy: 0.6475
# Epoch 9/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.6475
# Epoch 10/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5015 - accuracy: 0.6475
# Epoch 11/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.6475
# Epoch 12/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.6475
# Epoch 13/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.6475
# Epoch 14/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.6475
# Epoch 15/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4632 - accuracy: 0.7674
# Epoch 16/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7842
# Epoch 17/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4588 - accuracy: 0.7914
# Epoch 18/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4565 - accuracy: 0.7962
# Epoch 19/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4529 - accuracy: 0.7914
# Epoch 20/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7914
# Epoch 21/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4384 - accuracy: 0.7986
# Epoch 22/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4314 - accuracy: 0.7986
# Epoch 23/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4270 - accuracy: 0.7866
# Epoch 24/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.7938
# Epoch 25/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4218 - accuracy: 0.7962
# Epoch 26/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.7914
# Epoch 27/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4208 - accuracy: 0.8010
# Epoch 28/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4169 - accuracy: 0.7962
# Epoch 29/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8010
# Epoch 30/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4161 - accuracy: 0.8058
# Epoch 31/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.7986
# Epoch 32/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4146 - accuracy: 0.7938
# Epoch 33/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8010
# Epoch 34/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8058
# Epoch 35/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8034
# Epoch 36/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 0.8082
# Epoch 37/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4079 - accuracy: 0.8201
# Epoch 38/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4065 - accuracy: 0.8225
# Epoch 39/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8153
# Epoch 40/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8177
# Epoch 41/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4046 - accuracy: 0.8201
# Epoch 42/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.8225
# Epoch 43/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.7986
# Epoch 44/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4089 - accuracy: 0.8082
# Epoch 45/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8058
# Epoch 46/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.7650
# Epoch 47/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.7794
# Epoch 48/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.8082
# Epoch 49/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8010
# Epoch 50/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.8177
# Epoch 51/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8225
# Epoch 52/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8153
# Epoch 53/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3967 - accuracy: 0.8201
# Epoch 54/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8153
# Epoch 55/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8177
# Epoch 56/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8201
# Epoch 57/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8201
# Epoch 58/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8225
# Epoch 59/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8153
# Epoch 60/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8201
# Epoch 61/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3923 - accuracy: 0.8153
# Epoch 62/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3903 - accuracy: 0.8177
# Epoch 63/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3873 - accuracy: 0.8201
# Epoch 64/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.8249
# Epoch 65/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8273
# Epoch 66/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8177
# Epoch 67/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3870 - accuracy: 0.8201
# Epoch 68/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8225
# Epoch 69/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8297
# Epoch 70/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.8249
# Epoch 71/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.8273
# Epoch 72/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8273
# Epoch 73/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3802 - accuracy: 0.8297
# Epoch 74/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8249
# Epoch 75/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8273
# Epoch 76/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.8321
# Epoch 77/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8129
# Epoch 78/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8082
# Epoch 79/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3836 - accuracy: 0.8201
# Epoch 80/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8249
# Epoch 81/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.8249
# Epoch 82/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8201
# Epoch 83/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8249
# Epoch 84/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 0.8273
# Epoch 85/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3857 - accuracy: 0.8153
# Epoch 86/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8010
# Epoch 87/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3774 - accuracy: 0.8177
# Epoch 88/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.8297
# Epoch 89/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3831 - accuracy: 0.8153
# Epoch 90/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8177
# Epoch 91/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8321
# Epoch 92/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8393
# Epoch 93/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8369
# Epoch 94/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8393
# Epoch 95/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8393
# Epoch 96/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3582 - accuracy: 0.8441
# Epoch 97/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3551 - accuracy: 0.8393
# Epoch 98/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3522 - accuracy: 0.8441
# Epoch 99/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3565 - accuracy: 0.8417
# Epoch 100/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8417
# Epoch 101/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8369
# Epoch 102/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8465
# Epoch 103/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3430 - accuracy: 0.8441
# Epoch 104/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3652 - accuracy: 0.8297
# Epoch 105/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8369
# Epoch 106/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8297
# Epoch 107/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3487 - accuracy: 0.8321
# Epoch 108/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8369
# Epoch 109/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8393
# Epoch 110/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8465
# Epoch 111/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8489
# Epoch 112/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.8441
# Epoch 113/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8513
# Epoch 114/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3284 - accuracy: 0.8513
# Epoch 115/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3287 - accuracy: 0.8393
# Epoch 116/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3235 - accuracy: 0.8537
# Epoch 117/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3235 - accuracy: 0.8513
# Epoch 118/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3204 - accuracy: 0.8537
# Epoch 119/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3224 - accuracy: 0.8537
# Epoch 120/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3149 - accuracy: 0.8585
# Epoch 121/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3264 - accuracy: 0.8393
# Epoch 122/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8417
# Epoch 123/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3211 - accuracy: 0.8465
# Epoch 124/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3130 - accuracy: 0.8561
# Epoch 125/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.8537
# Epoch 126/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8609
# Epoch 127/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3135 - accuracy: 0.8537
# Epoch 128/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3291 - accuracy: 0.8465
# Epoch 129/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3148 - accuracy: 0.8489
# Epoch 130/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.8537
# Epoch 131/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3115 - accuracy: 0.8609
# Epoch 132/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3066 - accuracy: 0.8633
# Epoch 133/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.7602
# Epoch 134/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4066 - accuracy: 0.7746
# Epoch 135/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8034
# Epoch 136/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3543 - accuracy: 0.8201
# Epoch 137/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3466 - accuracy: 0.8177
# Epoch 138/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8297
# Epoch 139/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8345
# Epoch 140/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.8417
# Epoch 141/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8345
# Epoch 142/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8417
# Epoch 143/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3226 - accuracy: 0.8417
# Epoch 144/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8489
# Epoch 145/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.8489
# Epoch 146/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3149 - accuracy: 0.8513
# Epoch 147/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3121 - accuracy: 0.8561
# Epoch 148/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3104 - accuracy: 0.8489
# Epoch 149/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3083 - accuracy: 0.8489
# Epoch 150/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3069 - accuracy: 0.8537
# Epoch 151/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8561
# Epoch 152/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.8537
# Epoch 153/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3044 - accuracy: 0.8609
# Epoch 154/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.8537
# Epoch 155/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2983 - accuracy: 0.8633
# Epoch 156/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8489
# Epoch 157/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3095 - accuracy: 0.8633
# Epoch 158/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3017 - accuracy: 0.8609
# Epoch 159/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2995 - accuracy: 0.8585
# Epoch 160/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.8609
# Epoch 161/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.8465
# Epoch 162/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3294 - accuracy: 0.8465
# Epoch 163/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3118 - accuracy: 0.8561
# Epoch 164/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.8609
# Epoch 165/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2952 - accuracy: 0.8561
# Epoch 166/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2968 - accuracy: 0.8657
# Epoch 167/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2932 - accuracy: 0.8633
# Epoch 168/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.8633
# Epoch 169/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2935 - accuracy: 0.8537
# Epoch 170/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2904 - accuracy: 0.8753
# Epoch 171/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2880 - accuracy: 0.8633
# Epoch 172/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2853 - accuracy: 0.8681
# Epoch 173/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.8657
# Epoch 174/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2847 - accuracy: 0.8657
# Epoch 175/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2831 - accuracy: 0.8753
# Epoch 176/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2811 - accuracy: 0.8729
# Epoch 177/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2846 - accuracy: 0.8609
# Epoch 178/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2836 - accuracy: 0.8753
# Epoch 179/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2864 - accuracy: 0.8633
# Epoch 180/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.8729
# Epoch 181/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 0.8729
# Epoch 182/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8681
# Epoch 183/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2790 - accuracy: 0.8705
# Epoch 184/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8753
# Epoch 185/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.8729
# Epoch 186/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2777 - accuracy: 0.8705
# Epoch 187/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.8729
# Epoch 188/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2787 - accuracy: 0.8705
# Epoch 189/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2785 - accuracy: 0.8705
# Epoch 190/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8777
# Epoch 191/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2759 - accuracy: 0.8753
# Epoch 192/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2759 - accuracy: 0.8729
# Epoch 193/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.8753
# Epoch 194/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.8729
# Epoch 195/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2733 - accuracy: 0.8753
# Epoch 196/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2714 - accuracy: 0.8753
# Epoch 197/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.8705
# Epoch 198/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2753 - accuracy: 0.8705
# Epoch 199/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2710 - accuracy: 0.8777
# Epoch 200/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2706 - accuracy: 0.8753
# Epoch 201/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2752 - accuracy: 0.8729
# Epoch 202/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.8729
# Epoch 203/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2793 - accuracy: 0.8753
# Epoch 204/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.8681
# Epoch 205/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.6978
# Epoch 206/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5484 - accuracy: 0.6427
# Epoch 207/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4648 - accuracy: 0.6954
# Epoch 208/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.7410
# Epoch 209/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.7650
# Epoch 210/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.7674
# Epoch 211/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.7746
# Epoch 212/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8010
# Epoch 213/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.8129
# Epoch 214/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8034
# Epoch 215/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8153
# Epoch 216/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8153
# Epoch 217/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8297
# Epoch 218/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 0.8297
# Epoch 219/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3193 - accuracy: 0.8369
# Epoch 220/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.8465
# Epoch 221/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3183 - accuracy: 0.8417
# Epoch 222/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3092 - accuracy: 0.8465
# Epoch 223/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3067 - accuracy: 0.8417
# Epoch 224/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.8465
# Epoch 225/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8489
# Epoch 226/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3006 - accuracy: 0.8489
# Epoch 227/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.8537
# Epoch 228/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2968 - accuracy: 0.8561
# Epoch 229/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2957 - accuracy: 0.8561
# Epoch 230/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3072 - accuracy: 0.8633
# Epoch 231/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2940 - accuracy: 0.8561
# Epoch 232/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2984 - accuracy: 0.8561
# Epoch 233/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3037 - accuracy: 0.8585
# Epoch 234/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2981 - accuracy: 0.8681
# Epoch 235/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3097 - accuracy: 0.8465
# Epoch 236/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4671 - accuracy: 0.8393
# Epoch 237/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4317 - accuracy: 0.8225
# Epoch 238/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8010
# Epoch 239/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.8225
# Epoch 240/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8201
# Epoch 241/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3070 - accuracy: 0.8537
# Epoch 242/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.8585
# Epoch 243/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2947 - accuracy: 0.8609
# Epoch 244/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.8633
# Epoch 245/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2870 - accuracy: 0.8657
# Epoch 246/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2832 - accuracy: 0.8681
# Epoch 247/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2822 - accuracy: 0.8609
# Epoch 248/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.8729
# Epoch 249/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.8729
# Epoch 250/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2768 - accuracy: 0.8705
# Epoch 251/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2758 - accuracy: 0.8753
# Epoch 252/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.8753
# Epoch 253/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.8753
# Epoch 254/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2772 - accuracy: 0.8753
# Epoch 255/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2762 - accuracy: 0.8753
# Epoch 256/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.8729
# Epoch 257/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8753
# Epoch 258/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2769 - accuracy: 0.8681
# Epoch 259/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2738 - accuracy: 0.8729
# Epoch 260/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8753
# Epoch 261/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4596 - accuracy: 0.7218
# Epoch 262/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5198 - accuracy: 0.6715
# Epoch 263/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7218
# Epoch 264/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.7626
# Epoch 265/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.7962
# Epoch 266/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3402 - accuracy: 0.8106
# Epoch 267/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8345
# Epoch 268/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3087 - accuracy: 0.8369
# Epoch 269/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3001 - accuracy: 0.8537
# Epoch 270/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.8609
# Epoch 271/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2860 - accuracy: 0.8585
# Epoch 272/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2860 - accuracy: 0.8657
# Epoch 273/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8657
# Epoch 274/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8657
# Epoch 275/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.8681
# Epoch 276/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.8681
# Epoch 277/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2790 - accuracy: 0.8681
# Epoch 278/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8681
# Epoch 279/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2788 - accuracy: 0.8681
# Epoch 280/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2790 - accuracy: 0.8681
# Epoch 281/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.8681
# Epoch 282/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2792 - accuracy: 0.8681
# Epoch 283/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.8681
# Epoch 284/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8657
# Epoch 285/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.8681
# Epoch 286/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.8681
# Epoch 287/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.8681
# Epoch 288/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2772 - accuracy: 0.8681
# Epoch 289/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2769 - accuracy: 0.8681
# Epoch 290/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2767 - accuracy: 0.8681
# Epoch 291/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.8681
# Epoch 292/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8681
# Epoch 293/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.8681
# Epoch 294/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.8681
# Epoch 295/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8681
# Epoch 296/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8681
# Epoch 297/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.8681
# Epoch 298/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2759 - accuracy: 0.8681
# Epoch 299/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.8681
# Epoch 300/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2756 - accuracy: 0.8681
# Epoch 301/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2754 - accuracy: 0.8681
# Epoch 302/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.8681
# Epoch 303/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2752 - accuracy: 0.8681
# Epoch 304/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2753 - accuracy: 0.8681
# Epoch 305/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.8681
# Epoch 306/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2746 - accuracy: 0.8681
# Epoch 307/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.8681
# Epoch 308/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.8705
# Epoch 309/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.8681
# Epoch 310/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.8705
# Epoch 311/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2726 - accuracy: 0.8705
# Epoch 312/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2722 - accuracy: 0.8705
# Epoch 313/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.8705
# Epoch 314/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2722 - accuracy: 0.8705
# Epoch 315/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2726 - accuracy: 0.8705
# Epoch 316/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.8705
# Epoch 317/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.8705
# Epoch 318/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8705
# Epoch 319/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2718 - accuracy: 0.8705
# Epoch 320/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2718 - accuracy: 0.8705
# Epoch 321/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2714 - accuracy: 0.8705
# Epoch 322/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.8705
# Epoch 323/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8657
# Epoch 324/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2714 - accuracy: 0.8705
# Epoch 325/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2722 - accuracy: 0.8705
# Epoch 326/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.8729
# Epoch 327/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.8729
# Epoch 328/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.8753
# Epoch 329/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2658 - accuracy: 0.8753
# Epoch 330/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2658 - accuracy: 0.8753
# Epoch 331/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2659 - accuracy: 0.8753
# Epoch 332/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2656 - accuracy: 0.8753
# Epoch 333/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2658 - accuracy: 0.8753
# Epoch 334/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2655 - accuracy: 0.8753
# Epoch 335/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8753
# Epoch 336/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.8753
# Epoch 337/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.8753
# Epoch 338/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2643 - accuracy: 0.8753
# Epoch 339/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2641 - accuracy: 0.8753
# Epoch 340/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2641 - accuracy: 0.8753
# Epoch 341/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2638 - accuracy: 0.8753
# Epoch 342/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.8753
# Epoch 343/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2633 - accuracy: 0.8753
# Epoch 344/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.8753
# Epoch 345/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.8753
# Epoch 346/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.8753
# Epoch 347/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.8753
# Epoch 348/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2634 - accuracy: 0.8753
# Epoch 349/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.8753
# Epoch 350/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.8753
# Epoch 351/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2628 - accuracy: 0.8753
# Epoch 352/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2627 - accuracy: 0.8753
# Epoch 353/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.8753
# Epoch 354/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.8705
# Epoch 355/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2715 - accuracy: 0.8705
# Epoch 356/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.8705
# Epoch 357/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2757 - accuracy: 0.8681
# Epoch 358/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.8657
# Epoch 359/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3471 - accuracy: 0.8201
# Epoch 360/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3231 - accuracy: 0.8393
# Epoch 361/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3014 - accuracy: 0.8537
# Epoch 362/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2831 - accuracy: 0.8633
# Epoch 363/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2828 - accuracy: 0.8657
# Epoch 364/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.8681
# Epoch 365/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2793 - accuracy: 0.8705
# Epoch 366/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2767 - accuracy: 0.8705
# Epoch 367/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.8681
# Epoch 368/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2755 - accuracy: 0.8705
# Epoch 369/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.8705
# Epoch 370/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.8705
# Epoch 371/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.8705
# Epoch 372/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2746 - accuracy: 0.8705
# Epoch 373/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2743 - accuracy: 0.8705
# Epoch 374/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.8705
# Epoch 375/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8705
# Epoch 376/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8705
# Epoch 377/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2739 - accuracy: 0.8705
# Epoch 378/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2737 - accuracy: 0.8705
# Epoch 379/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2731 - accuracy: 0.8705
# Epoch 380/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8753
# Epoch 381/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8753
# Epoch 382/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2641 - accuracy: 0.8729
# Epoch 383/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.8753
# Epoch 384/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.8753
# Epoch 385/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.8753
# Epoch 386/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2617 - accuracy: 0.8753
# Epoch 387/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.8753
# Epoch 388/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.8753
# Epoch 389/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.8753
# Epoch 390/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.8753
# Epoch 391/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.8753
# Epoch 392/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2617 - accuracy: 0.8753
# Epoch 393/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2615 - accuracy: 0.8753
# Epoch 394/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.8753
# Epoch 395/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2605 - accuracy: 0.8753
# Epoch 396/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.8753
# Epoch 397/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.8729
# Epoch 398/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.8681
# Epoch 399/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.8753
# Epoch 400/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.8753
# Epoch 401/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8729
# Epoch 402/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3016 - accuracy: 0.8633
# Epoch 403/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2701 - accuracy: 0.8681
# Epoch 404/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2696 - accuracy: 0.8705
# Epoch 405/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.8753
# Epoch 406/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2668 - accuracy: 0.8729
# Epoch 407/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8657
# Epoch 408/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2703 - accuracy: 0.8657
# Epoch 409/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.8753
# Epoch 410/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2643 - accuracy: 0.8681
# Epoch 411/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2597 - accuracy: 0.8753
# Epoch 412/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2596 - accuracy: 0.8753
# Epoch 413/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2588 - accuracy: 0.8753
# Epoch 414/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.8753
# Epoch 415/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2575 - accuracy: 0.8753
# Epoch 416/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.8753
# Epoch 417/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.8753
# Epoch 418/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.8753
# Epoch 419/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.8753
# Epoch 420/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.8753
# Epoch 421/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.8753
# Epoch 422/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.8753
# Epoch 423/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2559 - accuracy: 0.8753
# Epoch 424/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.8753
# Epoch 425/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2552 - accuracy: 0.8753
# Epoch 426/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2549 - accuracy: 0.8753
# Epoch 427/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2549 - accuracy: 0.8753
# Epoch 428/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.8753
# Epoch 429/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.8753
# Epoch 430/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.8753
# Epoch 431/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.8753
# Epoch 432/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2540 - accuracy: 0.8753
# Epoch 433/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.8753
# Epoch 434/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.8753
# Epoch 435/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.8753
# Epoch 436/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.8753
# Epoch 437/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.8753
# Epoch 438/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2520 - accuracy: 0.8753
# Epoch 439/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.8753
# Epoch 440/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2510 - accuracy: 0.8753
# Epoch 441/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.8753
# Epoch 442/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.8753
# Epoch 443/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.8753
# Epoch 444/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.8753
# Epoch 445/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.8753
# Epoch 446/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.8753
# Epoch 447/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.8729
# Epoch 448/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.8753
# Epoch 449/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2504 - accuracy: 0.8753
# Epoch 450/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.8753
# Epoch 451/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.8753
# Epoch 452/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2485 - accuracy: 0.8753
# Epoch 453/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2468 - accuracy: 0.8753
# Epoch 454/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2470 - accuracy: 0.8753
# Epoch 455/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2464 - accuracy: 0.8753
# Epoch 456/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2459 - accuracy: 0.8753
# Epoch 457/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2449 - accuracy: 0.8753
# Epoch 458/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2446 - accuracy: 0.8753
# Epoch 459/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2442 - accuracy: 0.8753
# Epoch 460/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.8753
# Epoch 461/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2430 - accuracy: 0.8753
# Epoch 462/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.8753
# Epoch 463/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.8753
# Epoch 464/500
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2414 - accuracy: 0.8753
# Epoch 465/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.8753
# Epoch 466/500
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.8753
# Epoch 467/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2397 - accuracy: 0.8753
# Epoch 468/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.8753
# Epoch 469/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2447 - accuracy: 0.8729
# Epoch 470/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2398 - accuracy: 0.8777
# Epoch 471/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.8705
# Epoch 472/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.8777
# Epoch 473/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2608 - accuracy: 0.8801
# Epoch 474/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3350 - accuracy: 0.8417
# Epoch 475/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4571 - accuracy: 0.8129
# Epoch 476/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3738 - accuracy: 0.8225
# Epoch 477/500
# ...
# Epoch 345/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.8684
# Epoch 346/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.8780
# Epoch 347/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2769 - accuracy: 0.8804
# Epoch 348/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2704 - accuracy: 0.8852
# Epoch 349/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.8876
# Epoch 350/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2575 - accuracy: 0.8876
# Epoch 351/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.8828
# Epoch 352/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2480 - accuracy: 0.8900
# Epoch 353/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.8971
# Epoch 354/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.8971
# Epoch 355/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.8971
# Epoch 356/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.8971
# Epoch 357/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2252 - accuracy: 0.9019
# Epoch 358/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2258 - accuracy: 0.8995
# Epoch 359/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2247 - accuracy: 0.9043
# Epoch 360/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2322 - accuracy: 0.8900
# Epoch 361/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2328 - accuracy: 0.8947
# Epoch 362/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.8923
# Epoch 363/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2101 - accuracy: 0.8947
# Epoch 364/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.9115
# Epoch 365/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2115 - accuracy: 0.9019
# Epoch 366/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2084 - accuracy: 0.9043
# Epoch 367/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1948 - accuracy: 0.9091
# Epoch 368/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9115
# Epoch 369/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.9139
# Epoch 370/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1794 - accuracy: 0.9139
# Epoch 371/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 0.9163
# Epoch 372/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1809 - accuracy: 0.9187
# Epoch 373/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9234
# Epoch 374/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1809 - accuracy: 0.9282
# Epoch 375/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1752 - accuracy: 0.9258
# Epoch 376/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9282
# Epoch 377/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9211
# Epoch 378/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1735 - accuracy: 0.9258
# Epoch 379/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1708 - accuracy: 0.9306
# Epoch 380/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1669 - accuracy: 0.9330
# Epoch 381/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1674 - accuracy: 0.9211
# Epoch 382/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1659 - accuracy: 0.9354
# Epoch 383/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.9354
# Epoch 384/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9378
# Epoch 385/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1666 - accuracy: 0.9211
# Epoch 386/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1623 - accuracy: 0.9306
# Epoch 387/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1582 - accuracy: 0.9378
# Epoch 388/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1583 - accuracy: 0.9354
# Epoch 389/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9330
# Epoch 390/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1542 - accuracy: 0.9426
# Epoch 391/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9378
# Epoch 392/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1547 - accuracy: 0.9354
# Epoch 393/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9378
# Epoch 394/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9402
# Epoch 395/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1524 - accuracy: 0.9378
# Epoch 396/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1531 - accuracy: 0.9402
# Epoch 397/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1510 - accuracy: 0.9354
# Epoch 398/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1514 - accuracy: 0.9426
# Epoch 399/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.9426
# Epoch 400/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.9402
# Epoch 401/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1463 - accuracy: 0.9450
# Epoch 402/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1476 - accuracy: 0.9402
# Epoch 403/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1462 - accuracy: 0.9450
# Epoch 404/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.9450
# Epoch 405/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9450
# Epoch 406/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9402
# Epoch 407/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9426
# Epoch 408/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1437 - accuracy: 0.9426
# Epoch 409/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9450
# Epoch 410/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1387 - accuracy: 0.9426
# Epoch 411/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.9330
# Epoch 412/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2547 - accuracy: 0.9091
# Epoch 413/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3041 - accuracy: 0.8852
# Epoch 414/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.8900
# Epoch 415/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.8995
# Epoch 416/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2094 - accuracy: 0.9258
# Epoch 417/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1967 - accuracy: 0.9187
# Epoch 418/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.9282
# Epoch 419/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3792 - accuracy: 0.8660
# Epoch 420/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2397 - accuracy: 0.9067
# Epoch 421/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2164 - accuracy: 0.9139
# Epoch 422/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2056 - accuracy: 0.9163
# Epoch 423/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1818 - accuracy: 0.9258
# Epoch 424/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9354
# Epoch 425/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.9330
# Epoch 426/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1623 - accuracy: 0.9402
# Epoch 427/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1584 - accuracy: 0.9450
# Epoch 428/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1593 - accuracy: 0.9402
# Epoch 429/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.9354
# Epoch 430/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1504 - accuracy: 0.9498
# Epoch 431/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9426
# Epoch 432/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9474
# Epoch 433/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9522
# Epoch 434/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9450
# Epoch 435/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9402
# Epoch 436/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1379 - accuracy: 0.9474
# Epoch 437/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9522
# Epoch 438/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1339 - accuracy: 0.9545
# Epoch 439/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1320 - accuracy: 0.9522
# Epoch 440/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9522
# Epoch 441/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9522
# Epoch 442/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9545
# Epoch 443/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.9522
# Epoch 444/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1294 - accuracy: 0.9522
# Epoch 445/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9545
# Epoch 446/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9545
# Epoch 447/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9545
# Epoch 448/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1165 - accuracy: 0.9545
# Epoch 449/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9569
# Epoch 450/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1164 - accuracy: 0.9569
# Epoch 451/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.9545
# Epoch 452/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.9569
# Epoch 453/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.9545
# Epoch 454/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1148 - accuracy: 0.9522
# Epoch 455/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9569
# Epoch 456/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9545
# Epoch 457/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9593
# Epoch 458/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1194 - accuracy: 0.9498
# Epoch 459/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1164 - accuracy: 0.9593
# Epoch 460/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9545
# Epoch 461/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9593
# Epoch 462/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9593
# Epoch 463/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1057 - accuracy: 0.9665
# Epoch 464/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9569
# Epoch 465/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.9545
# Epoch 466/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3428 - accuracy: 0.8852
# Epoch 467/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.8923
# Epoch 468/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9091
# Epoch 469/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1826 - accuracy: 0.9234
# Epoch 470/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1801 - accuracy: 0.9426
# Epoch 471/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1479 - accuracy: 0.9498
# Epoch 472/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1395 - accuracy: 0.9474
# Epoch 473/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1281 - accuracy: 0.9498
# Epoch 474/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1370 - accuracy: 0.9474
# Epoch 475/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9617
# Epoch 476/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9617
# Epoch 477/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9617
# Epoch 478/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9665
# Epoch 479/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9665
# Epoch 480/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0993 - accuracy: 0.9665
# Epoch 481/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9641
# Epoch 482/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0975 - accuracy: 0.9665
# Epoch 483/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.9689
# Epoch 484/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9689
# Epoch 485/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9593
# Epoch 486/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 0.9689
# Epoch 487/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9689
# Epoch 488/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.9689
# Epoch 489/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 0.9689
# Epoch 490/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9713
# Epoch 491/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.9641
# Epoch 492/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9713
# Epoch 493/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1019 - accuracy: 0.9617
# Epoch 494/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9641
# Epoch 495/500
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0912 - accuracy: 0.9665
# Epoch 496/500
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0900 - accuracy: 0.9689
# Epoch 497/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9761
# Epoch 498/500
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0869 - accuracy: 0.9761
# Epoch 499/500
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0850 - accuracy: 0.9737
# Epoch 500/500
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9737
# 4/4 [==============================] - 0s 3ms/step - loss: 3.2379 - accuracy: 0.6635
# Accuracy mean: 0.6953113675117493
# Accuracy variance: 0.06824588720367347

# %% [markdown]
# # ML Algorithms F1-Scores

# %%
#F1-Score For Logistic Regression
from sklearn.metrics import f1_score
LRf1 = f1_score(ytrue, yprediciton1, average='weighted') 
LRf1
# Out:
# 0.8053265153936294

# %%
#K-NN
KNNf1= f1_score(ytrue, yprediciton2, average='weighted') 
KNNf1
# Out:
# 0.6675647451963242

# %%
#SVM
SVMf1=f1_score(ytrue, yprediciton3, average='weighted') 
SVMf1
# Out:
# 0.7839161662545626

# %%
#naive bayes
NBf1 = f1_score(ytrue, yprediciton4, average='weighted') 
NBf1
# Out:
# 0.7476739131983782

# %%
#Decision Tree
DTf1=f1_score(ytrue, yprediciton5, average='weighted') 
DTf1
# Out:
# 0.7151863367718629

# %%
#RandomForest
RFf1=f1_score(ytrue, yprediciton6, average='weighted') 
RFf1
# Out:
# 0.8180284219399611

# %% [markdown]
# # Scatter Plot For Comparasion of ML Algorithms Prediciton Scores

# %%
scores=[LRscore,KNNscore,SVMscore,NBscore,DTCscore,RFCscore,mean]
AlgorthmsName=["Logistic Regression","K-NN","SVM","Naive Bayes","Decision Tree", "Random Forest","Artificial Neural Network"]

#create traces

trace1 = go.Scatter(
    x = AlgorthmsName,
    y= scores,
    name='Algortms Name',
    marker =dict(color='rgba(0,255,0,0.5)',
               line =dict(color='rgb(0,0,0)',width=2)),
                text=AlgorthmsName
)
data = [trace1]

layout = go.Layout(barmode = "group",
                  xaxis= dict(title= 'ML Algorithms',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'Prediction Scores',ticklen= 5,zeroline= False))
fig = go.Figure(data = data, layout = layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5548/3376207535.py in <module>
#      18               yaxis= dict(title= 'Prediction Scores',ticklen= 5,zeroline= False))
#      19 fig = go.Figure(data = data, layout = layout)
# ---> 20 iplot(fig)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\offline\offline.py in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config, auto_play, animation_opts)
#     390
#     391     # Show figure
# --> 392     pio.show(
#     393         figure,
#     394         validate=validate,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     395
#     396         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 397             raise ValueError(
#     398                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     399             )
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# # Scatter Plot For Comparasion of ML Algorithms Prediciton Scores (F1)

# %%
scoresf1=[LRf1,KNNf1,SVMf1,NBf1,DTf1,RFf1]
#create traces

trace1 = go.Scatter(
    x = AlgorthmsName,
    y= scoresf1,
    name='Algortms Name',
    marker =dict(color='rgba(225,126,0,0.5)',
               line =dict(color='rgb(0,0,0)',width=2)),
                text=AlgorthmsName
)
data = [trace1]

layout = go.Layout(barmode = "group", 
                  xaxis= dict(title= 'ML Algorithms',ticklen= 5,zeroline= False),
              yaxis= dict(title= 'Prediction Scores(F1)',ticklen= 5,zeroline= False))
fig = go.Figure(data = data, layout = layout)
iplot(fig)
